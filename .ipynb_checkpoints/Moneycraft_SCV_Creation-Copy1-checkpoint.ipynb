# %%
# !pip install -q uv
# !uv pip install --system tensorflow-data-validation
# Out:
# Using Python 3.11.13 environment at: /usr
# Checked 1 package in 300ms

# %%
#
import pandas as pd
import numpy as np
import tensorflow_data_validation as tfdv
# Out:
# WARNING:root:crcmod package not found. This package is required if python-snappy or google-crc32c are not installed. To ensure crcmod is installed, install the tfrecord extra: pip install apache-beam[tfrecord]

# %%
df_acc = pd.read_csv('moneycraft_accounts.csv')
df_acc['month'] = pd.PeriodIndex(df_acc['month'], freq='M')
df_acc.head()
# Out:
#    customer_id    month acquisition_channel      region age_band account_tier  \
# 0            1  2022-01     Comparison Site    Scotland    25-34      Classic
# 1            2  2022-01              Online      London    55-64       Silver
# 2            3  2022-01              Branch  South East    25-34     Platinum
# 3            4  2022-01            Referral      London    25-34       Silver
# 4            5  2022-01     Comparison Site  South East    35-44       Silver
#
#    monthly_fee  joined_on_promo
# 0            0            False
# 1           11            False
# 2           28            False
# 3            0             True
# 4           11            False

# %%
df_mark = pd.read_csv('moneycraft_marketing_spend.csv')
df_mark['month'] = pd.PeriodIndex(df_mark['month'], freq='M')
df_mark.head()
# Out:
#      month          channel  spend_gbp
# 0  2022-01           Branch     7310.0
# 1  2022-01       Broker/IFA     4014.0
# 2  2022-01  Comparison Site     3162.0
# 3  2022-01           Online     3945.0
# 4  2022-01         Outbound     4899.0

# %%
switches = (df_acc.sort_values(['customer_id', 'month'])
                  .groupby('customer_id')['account_tier']
                  .apply(lambda s: (s != s.shift()).sum() - 1))

switches.head(20)
# Out:
# customer_id
# 1     0
# 2     2
# 3     2
# 4     0
# 5     1
# 6     2
# 7     0
# 8     1
# 9     2
# 10    1
# 11    0
# 12    0
# 13    0
# 14    3
# 15    0
# 16    0
# 17    0
# 18    1
# 19    2
# 20    3
# Name: account_tier, dtype: int64

# %%
df_acc['customer_id'].nunique()
#15732
# Out:
# 15732

# %%
df_acc.dtypes
# Out:
# customer_id                int64
# month                  period[M]
# acquisition_channel       object
# region                    object
# age_band                  object
# account_tier              object
# monthly_fee                int64
# joined_on_promo             bool
# dtype: object

# %%
df_acc = df_acc.sort_values(['customer_id', 'month'])
df_acc
# Out:
#         customer_id    month acquisition_channel      region age_band  \
# 0                 1  2022-01     Comparison Site    Scotland    25-34
# 280               1  2022-02     Comparison Site    Scotland    25-34
# 840               1  2022-03     Comparison Site    Scotland    25-34
# 1664              1  2022-04     Comparison Site    Scotland    25-34
# 2750              1  2022-05     Comparison Site    Scotland    25-34
# ...             ...      ...                 ...         ...      ...
# 179013        15728  2024-12            Outbound    Midlands    35-44
# 179014        15729  2024-12     Comparison Site    Midlands    25-34
# 179015        15730  2024-12            Referral      London    25-34
# 179016        15731  2024-12              Online  South East    55-64
# 179017        15732  2024-12     Comparison Site       North    55-64
#
#        account_tier  monthly_fee  joined_on_promo
# 0           Classic            0            False
# 280         Classic            0            False
# 840         Classic            0            False
# 1664        Classic            0            False
# 2750        Classic            0            False
# ...             ...          ...              ...
# 179013       Silver            0             True
# 179014      Classic            0             True
# 179015         Gold           18            False
# 179016     Platinum           28            False
# 179017     Platinum            0             True
#
# [179018 rows x 8 columns]

# %%
grouped = df_acc.groupby('customer_id')

# A few simple summaries, one per customer:
signup_month  = grouped['month'].min()    # their FIRST month
last_active   = grouped['month'].max()    # their LAST month
tenure_months = grouped['month'].count()  # how many months in total

signup_month.head()
# Out:
# customer_id
# 1    2022-01
# 2    2022-01
# 3    2022-01
# 4    2022-01
# 5    2022-01
# Name: month, dtype: period[M]

# %%
grouped['joined_on_promo'].first()
# Out:
# customer_id
# 1        False
# 2        False
# 3        False
# 4         True
# 5        False
#          ...
# 15728     True
# 15729     True
# 15730    False
# 15731    False
# 15732     True
# Name: joined_on_promo, Length: 15732, dtype: bool

# %%
channel    = grouped['acquisition_channel'].first() # Assuming they haven't rejoined using a different channel
region     = grouped['region'].first() # Assuming they haven't moved
age_band   = grouped['age_band'].first() # Assuming they haven't aged
first_plan = grouped['account_tier'].first()   # the plan they STARTED on
last_plan  = grouped['account_tier'].last()    # the plan they ENDED on
promo_join = grouped['joined_on_promo'].first() # whether they joined on promo


first_plan.head()
# Out:
# customer_id
# 1     Classic
# 2      Silver
# 3    Platinum
# 4      Silver
# 5      Silver
# Name: account_tier, dtype: object

# %%
# 1. Identify where a tier change occurs
tier_changed = df_acc['account_tier'] != df_acc.groupby('customer_id')['account_tier'].shift()

# 2. Group into a clean Python list per customer
plan_history_list = df_acc[tier_changed].groupby('customer_id')['account_tier'].apply(list)
plan_history_list
# Out:
# customer_id
# 1                         [Classic]
# 2          [Silver, Gold, Platinum]
# 3        [Platinum, Gold, Platinum]
# 4                          [Silver]
# 5                 [Silver, Classic]
#                     ...
# 15728                      [Silver]
# 15729                     [Classic]
# 15730                        [Gold]
# 15731                    [Platinum]
# 15732                    [Platinum]
# Name: account_tier, Length: 15732, dtype: object

# %%
total_revenue = grouped['monthly_fee'].sum()   # everything they ever paid us
max_paid      = grouped['monthly_fee'].max()   # the most they ever paid in a month

total_revenue.head()
# Out:
# customer_id
# 1      0
# 2    595
# 3    848
# 4    330
# 5     33
# Name: monthly_fee, dtype: int64

# %%
scv = pd.DataFrame({
    'signup_month' : signup_month,
    'last_active'  : last_active,
    'tenure_months': tenure_months,
    'channel'      : channel,
    'region'       : region,
    'age_band'     : age_band,
    'first_plan'   : first_plan,
    'last_plan'    : last_plan,
    'total_revenue': total_revenue,
    'promo_join'   : promo_join,
    'plan_history' : plan_history_list
})

# A handy True/False column: did they EVER actually pay us?
scv['ever_paid'] = max_paid > 0

scv.head()
# Out:
#             signup_month last_active  tenure_months          channel  \
# customer_id
# 1                2022-01     2022-06              6  Comparison Site
# 2                2022-01     2024-12             36           Online
# 3                2022-01     2024-12             36           Branch
# 4                2022-01     2024-12             36         Referral
# 5                2022-01     2022-10             10  Comparison Site
#
#                  region age_band first_plan last_plan  total_revenue  \
# customer_id
# 1              Scotland    25-34    Classic   Classic              0
# 2                London    55-64     Silver  Platinum            595
# 3            South East    25-34   Platinum  Platinum            848
# 4                London    25-34     Silver    Silver            330
# 5            South East    35-44     Silver   Classic             33
#
#              promo_join                plan_history  ever_paid
# customer_id
# 1                 False                   [Classic]      False
# 2                 False    [Silver, Gold, Platinum]       True
# 3                 False  [Platinum, Gold, Platinum]       True
# 4                  True                    [Silver]       True
# 5                 False           [Silver, Classic]       True

# %%
# 1. Define the condition for successful promo retention
is_promo = scv['promo_join'] == True
stayed_past_free = scv['tenure_months'] > 6

# 2. Use np.where: True if retained, False if they left early, None/NaN if not a promo customer
scv['retained_after_promo'] = np.where(is_promo, stayed_past_free, None)

# %%
final_month = df_acc['month'].max()          # the last month we can see in the data
print('Final month in the data:', final_month)

scv['churned'] = scv['last_active'] < final_month   # True if they left before the end
scv[['signup_month', 'last_active', 'tenure_months', 'churned']].head()
# Out:
# Final month in the data: 2024-12
#             signup_month last_active  tenure_months  churned
# customer_id
# 1                2022-01     2022-06              6     True
# 2                2022-01     2024-12             36    False
# 3                2022-01     2024-12             36    False
# 4                2022-01     2024-12             36    False
# 5                2022-01     2022-10             10     True

# %%
scv.head()
# Out:
#             signup_month last_active  tenure_months          channel  \
# customer_id
# 1                2022-01     2022-06              6  Comparison Site
# 2                2022-01     2024-12             36           Online
# 3                2022-01     2024-12             36           Branch
# 4                2022-01     2024-12             36         Referral
# 5                2022-01     2022-10             10  Comparison Site
#
#                  region age_band first_plan last_plan  total_revenue  \
# customer_id
# 1              Scotland    25-34    Classic   Classic              0
# 2                London    55-64     Silver  Platinum            595
# 3            South East    25-34   Platinum  Platinum            848
# 4                London    25-34     Silver    Silver            330
# 5            South East    35-44     Silver   Classic             33
#
#              promo_join                plan_history  ever_paid  churned  \
# customer_id
# 1                 False                   [Classic]      False     True
# 2                 False    [Silver, Gold, Platinum]       True    False
# 3                 False  [Platinum, Gold, Platinum]       True    False
# 4                  True                    [Silver]       True    False
# 5                 False           [Silver, Classic]       True     True
#
#             retained_after_promo
# customer_id
# 1                           None
# 2                           None
# 3                           None
# 4                           True
# 5                           None
